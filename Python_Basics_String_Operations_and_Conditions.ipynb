# %% [markdown]
# <a href="https://colab.research.google.com/github/KavyaSmruthi694/ICP-1/blob/main/700772834_Assignment01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
s = input("Enter a string: ")
char_list = list(s)
del char_list[3:5]
char_list.reverse()
result_string = "".join(char_list)
print("Resultant string:", result_string)


# PART 2: Arithmetic operations
a = input("Enter first number: ")
b = input("Enter second number: ")

a = int(a)
b = int(b)

c = a + b
d = a * b

print("Addition:", c)
print("Multiplication:", d)
# Out:
# Enter a string: python
# Resultant string: ntyp
# Enter first number: 5
# Enter second number: 5
# Addition: 10
# Multiplication: 25

# %%
sentence = input("      ")
new_sentence = sentence.replace("python", "pythons")
new_sentence = new_sentence.replace("PYTHON", "PYTHONS")
print(new_sentence)
# Out:
#       i love playing with python
# i love playing with pythons

# %%
score = float(input("Enter your class score: "))
if score >= 85:
    grade = "A"
elif score >= 75:
    grade = "B"
elif score >= 65:
    grade = "C"
else:
    grade = "F"
print("Your grade is:", grade)
# Out:
# Enter your class score: 99.9
# Your grade is: A
